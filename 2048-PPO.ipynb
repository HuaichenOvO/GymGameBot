# %% [markdown]
# ## Register gym environment

# %%
import gym
import sys
from gym.envs.registration import register
sys.path.append('./Base2048Env')
import Base2048Env
register(
    id='2048-v0',
    entry_point='Base2048Env:Base2048Env'
)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical

# %%
# torch.__version__
torch.cuda.is_available()
# Out:
# True

# %%
class PPOAgent:
    def __init__(self, state_dim, action_dim, lr=1e-4, gamma=0.99, clip_epsilon=0.2, update_epochs=4):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.clip_epsilon = clip_epsilon
        self.update_epochs = update_epochs

        # Define policy and value networks
        self.policy_net = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, action_dim),
            nn.Softmax(dim=-1)
        ).to('cuda')

        self.value_net = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        ).to('cuda')

        # Optimizers
        self.policy_optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.value_optimizer = optim.Adam(self.value_net.parameters(), lr=lr)

    def select_action(self, state_tensor):
        """Select action and compute log probabilities."""
        probs = self.policy_net(state_tensor)  # Shape [batch_size, action_dim]

        # Sample actions from the probability distribution
        dist = torch.distributions.Categorical(probs)
        action = dist.sample()  # Shape [batch_size]
        log_prob = dist.log_prob(action)  # Shape [batch_size]

        return action, log_prob, probs

    def compute_advantages_and_returns(self, rewards, dones, values, next_value):
        """Compute advantages and returns using the Generalized Advantage Estimation (GAE)."""
        rewards = np.array(rewards)  # Shape [timesteps, batch_size]
        dones = np.array(dones)  # Shape [timesteps, batch_size]
        values = np.array(values)  # Shape [timesteps, batch_size]
        next_value = np.array(next_value)
        next_value = np.expand_dims(next_value, axis=0)
        values = np.concatenate((values, next_value), axis=0)

        # Initialize advantages and returns
        timesteps, batch_size = rewards.shape
        advantages = np.zeros_like(rewards)  # Shape: [timesteps, batch_size]
        returns = np.zeros_like(rewards)  # Shape: [timesteps, batch_size]

        running_return = np.array(next_value).squeeze()  # Shape: [batch_size]
        running_advantage = np.zeros(batch_size).squeeze()  # Shape: [batch_size]

        for t in reversed(range(timesteps)):
            mask = 1 - dones[t]
            running_return = rewards[t] + self.gamma * running_return * mask
            delta = self.gamma * np.multiply(values[t+1].squeeze(), mask.squeeze())
            td_error = rewards[t] + delta - values[t].squeeze()
            running_advantage = td_error + self.gamma * self.clip_epsilon * running_advantage * mask

            returns[t] = running_return
            advantages[t] = running_advantage

        return torch.tensor(advantages, dtype=torch.float32).to('cuda'), torch.tensor(returns, dtype=torch.float32).to('cuda')


    def optimize(self, states, actions, log_probs, advantages, returns):
        """Optimize the policy and value networks."""
        for _ in range(self.update_epochs):
            # Compute current log probabilities and entropy
            print("states", states)
            probs = self.policy_net(states)  # Shape [batch_size * timesteps, action_dim]
            print("probs", probs)
            dist = torch.distributions.Categorical(probs)
            print("dist", dist)
            print("actions", actions)
            new_log_probs = dist.log_prob(actions.view(-1))  # Flatten for batch processing
            print("new_log_probs", new_log_probs)
            entropy = dist.entropy().mean()
            print("entropy", entropy) 

            # Compute policy loss with clipping
            ratio = (new_log_probs - log_probs.flatten()).exp()  # Flatten for batch comparison
            clipped_ratio = torch.clamp(ratio, 1 - self.clip_epsilon, 1 + self.clip_epsilon)
            policy_loss = -torch.min(ratio * advantages.flatten(), clipped_ratio * advantages.flatten()).mean()

            # Compute value loss (Mean Squared Error)
            values = self.value_net(states).squeeze(-1)  # Shape [batch_size * timesteps]
            value_loss = nn.functional.mse_loss(values, returns.flatten())

            # Update policy network
            self.policy_optimizer.zero_grad()
            (policy_loss - 0.01 * entropy).backward()
            self.policy_optimizer.step()

            # Update value network
            self.value_optimizer.zero_grad()
            value_loss.backward()
            self.value_optimizer.step()

# %%
agent = PPOAgent(state_dim=16, action_dim=4)
env = gym.make("2048-v0")
train_agent(agent, env, max_episodes=1000)
# Out:
# c:\Users\Huaichen\Desktop\gym\Base2048Env.py:125: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   board[tile_locs] = tiles
# c:\Python310\lib\site-packages\gym\utils\passive_env_checker.py:31: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (4, 4)
#   logger.warn(
# c:\Python310\lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# ...

# %%
import torch
import numpy as np

# Define the batch size (20 parallel games)
batch_size = 20

def run_game(agent, env, state, done, batch_size):
    """
    Function to handle a single game (episode) for the PPO agent.

    Parameters:
        agent: The PPO agent
        env: The environment (OpenAI Gym 2048)
        state: Initial state of the environment
        done: Done flags for each game
        batch_size: Number of parallel games

    Returns:
        states, actions, rewards, log_probs, dones, values: Collected data from the game
    """
    actions, rewards, log_probs, dones, values = [], [], [], [], []
    states_tensor = torch.tensor(state, dtype=torch.float32).to('cuda')  # Shape [batch_size, state_size]

    action_times = 0

    while not done.all():  # Continue while any game is not done
        action_times += 1
        print(f"action_times: {action_times}")
        # Select actions for all games in parallel
        action, log_prob, _ = agent.select_action(states_tensor)  # Shape: [batch_size]

        # Take actions in the environment (in parallel for all games)
        next_states, reward, done_flags, _ = zip(*[env.step(a) for a in action])
        next_states = np.array([state.flatten() for state in next_states])  # Shape [batch_size, state_size]
        reward = np.array(reward)  # Shape [batch_size]
        done_flags = np.array(done_flags)  # Shape [batch_size]
        
        # Save trajectory for each game in the batch
        actions.append(action.cpu().numpy())
        rewards.append(reward)
        log_probs.append(log_prob.cpu().detach().numpy())
        dones.append(done_flags)
        
        # Get value predictions for current states
        state_values = agent.value_net(states_tensor).cpu().detach().numpy()  # Shape [batch_size]
        values.append(state_values)
        
        # Update states, done flags, and scores
        states_tensor = torch.tensor(next_states, dtype=torch.float32).to('cuda')  # Move to GPU
        done = done_flags

    # After the game loop, compute the final value estimates for the last state
    next_value = agent.value_net(torch.tensor(next_states, dtype=torch.float32).to('cuda')).cpu().detach().numpy()

    return states_tensor, actions, rewards, log_probs, dones, values, next_value

def train_agent(agent, env, max_episodes=1000):
    """
    Function to train the PPO agent over multiple episodes.

    Parameters:
        agent: The PPO agent
        env: The environment (OpenAI Gym 2048)
        max_episodes: Number of episodes to train the agent
    """
    for episode in range(max_episodes):
        # Initialize the environment and reset the states for the batch of games
        init_state = np.array([env.reset().flatten() for _ in range(batch_size)])  # Shape [batch_size, state_size]
        done = np.zeros(batch_size, dtype=bool)  # Done flag for each game
        score = np.zeros(batch_size)  # Scores for each game
        
        # Run the game (this will collect the trajectory for each game)
        states, actions, rewards, log_probs, dones, values, next_value = run_game(agent, env, init_state, done, batch_size)
        print("values", values)
        print("next_value", next_value)
        
        # Compute advantages and returns
        advantages, returns = agent.compute_advantages_and_returns(rewards, dones, values, next_value)

        # Convert everything to tensors on GPU for optimization
        states_tensor = torch.tensor(states, dtype=torch.float32).to('cuda')
        actions_tensor = torch.tensor(np.array(actions), dtype=torch.int64).to('cuda')
        log_probs_tensor = torch.tensor(np.array(log_probs), dtype=torch.float32).to('cuda')
        advantages_tensor = torch.tensor(advantages, dtype=torch.float32).to('cuda')
        returns_tensor = torch.tensor(returns, dtype=torch.float32).to('cuda')

        # Perform optimization for policy and value networks
        agent.optimize(states_tensor, actions_tensor, log_probs_tensor, advantages_tensor, returns_tensor)

        print(f"finished optimizing {episode+1} episodes")
